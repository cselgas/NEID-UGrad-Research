# %%
# Import Numpy and Matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Astropy for FITS handling and modeling
from astropy.io import fits
from astropy.modeling import models, fitting
from astropy import modeling

# Model fitting
from scipy.signal import savgol_filter
from scipy.interpolate import CubicSpline
from astropy.modeling import models, fitting
from astropy import modeling
from lmfit.models import SkewedGaussianModel

# Import Pandas to work with AFS algorithm
import pandas as pd

# Import Scipy and Numpy derivative works
import scipy.optimize
from scipy.signal import savgol_filter
from scipy.misc import derivative
from numpy import diff

# Import Numpy Integration
from numpy import trapz

# Import Models for Fitting
from lmfit.models import GaussianModel, SkewedGaussianModel, VoigtModel

# Import Time
import time

# Import to Work Across Files
import os

# Access HPC Files
from glob import glob

# %%
# Choose Graph and Plotting Style
plt.style.use(['ggplot'])

# %%
# Define Path for Noon Files
path = '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/'
glob(path+'*')
# Out:
# ['/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T194658.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210302T192010.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210110T194341.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210323T192318.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210204T193723.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210112T195346.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210626T194331.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210605T192351.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210213T192536.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210530T192230.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201225T194058.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210304T194848.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210102T194027.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201229T193650.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210513T193606.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210615T194852.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/wget-log',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210521T192624.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210111T195210.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210122T193743.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210521T192758.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210210T192855.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210619T192352.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210208T194127.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210612T192313.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210121T194732.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210315T192643.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T192402.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210401T195059.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210212T193947.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210219T192929.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210502T192609.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210614T194110.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201218T195041.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210609T193524.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210429T194252.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210402T192712.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210605T191911.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201217T193440.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210328T192536.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210204T194509.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210518T192921.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210309T192141.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210430T193030.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T192029.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T194446.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210510T194647.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210713T193542.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T192017.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210704T194157.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210806T193024.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210730T193606.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210506T195226.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210210T192242.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210128T193741.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210116T192657.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210802T192319.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210805T192012.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210225T195211.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210608T192146.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210613T192428.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210207T192717.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210623T193639.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210524T194808.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T192741.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201214T194209.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210111T193809.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210121T193504.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210324T194056.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T194022.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210320T195322.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210329T193803.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210317T192339.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T194333.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210617T193705.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210219T193543.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210421T192631.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210720T192244.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T192624.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201227T194339.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210202T191958.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210417T195430.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210220T193458.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210111T195036.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210117T192708.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210730T195003.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210418T195105.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210729T194910.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210730T192953.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201222T194124.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210202T194320.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210609T192429.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201226T192620.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210514T195136.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210606T194421.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210206T194021.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201221T194951.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210317T192032.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210317T191858.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T195226.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210413T192022.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210321T193333.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210515T192518.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210206T192312.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T194725.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210122T194810.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210314T195027.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210321T192854.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T194007.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210613T192121.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210205T192820.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201227T193418.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210629T193951.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210531T194344.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T194642.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210109T192154.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210105T192453.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210707T193055.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T192317.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210109T193113.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210302T193104.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210406T192550.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210711T194535.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T192816.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210613T193830.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210216T193728.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210329T193151.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210707T194148.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210602T193615.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210319T195031.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210328T194720.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210515T194051.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210102T192628.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210315T194048.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210617T193052.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210313T194118.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210205T191900.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210123T193115.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210704T194503.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210317T192819.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210304T192329.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T193715.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210527T193903.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210524T192756.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210116T193618.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201213T193018.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201225T193618.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210430T192856.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210802T193717.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210628T194851.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210426T193851.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210513T192339.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210711T193746.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210516T193213.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210221T194821.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210319T192639.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210403T195319.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T191958.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210801T193459.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210706T194915.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210611T193509.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210324T194709.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201221T194231.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210309T194941.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T195059.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201222T195217.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210610T193351.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210128T192014.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210402T194109.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210504T193146.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210616T194816.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210710T194155.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210704T193850.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210621T194458.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210519T193631.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201213T195318.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210111T193943.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210202T192613.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210110T193554.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210521T194026.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210720T194606.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210321T193945.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210315T192335.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201227T193726.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210112T194734.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210710T192754.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210530T191923.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210603T194453.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210120T192545.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210213T193604.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T193431.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210129T194837.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210113T193707.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210405T191845.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210423T192415.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210619T193140.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210114T194510.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210113T194147.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210731T194801.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201215T195320.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210604T193130.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210704T195425.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210513T192953.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210511T193238.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210620T194946.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210114T193657.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210421T192150.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210210T194255.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210228T192516.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210512T192404.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T195232.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210316T193606.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210621T194804.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210623T194428.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210101T193813.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T193652.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210216T192459.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T195425.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210720T193952.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T194658.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210628T192530.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210713T195423.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210326T194236.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210214T195318.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210413T194035.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210120T194116.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210616T194202.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210224T195110.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T193738.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210109T192500.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210406T193335.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210513T195313.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210523T192501.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210105T193721.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210129T194530.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210320T193442.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210617T193224.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210623T192717.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T193244.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T192950.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210206T193541.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210313T193945.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210607T194426.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201219T194536.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210224T195417.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210103T194321.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210115T194915.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210207T193812.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201222T194737.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T193912.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210211T194520.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210711T192517.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210612T192446.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210308T192442.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T193629.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T193122.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210310T192243.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210403T192224.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210523T194648.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210123T192501.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T193259.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T193606.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210606T194248.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210225T193617.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210514T194656.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210526T191941.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210601T194618.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210701T193208.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201212T193855.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210709T194905.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210413T194939.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210314T193457.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T193322.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201220T192129.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210602T192040.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210421T192457.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210304T194541.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210507T192637.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210302T193851.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210112T193639.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210507T193250.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210102T194843.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210312T192509.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210109T194339.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210514T194348.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T193430.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210228T193304.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210308T192002.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210524T195115.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210709T192544.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210303T193939.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201222T192427.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201213T192539.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210116T192350.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210517T192151.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210421T193111.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210205T193741.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210304T192155.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210207T194119.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210619T195023.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210506T193822.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T192304.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210603T194146.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210417T193527.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210403T193009.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201218T194102.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210311T192023.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T194219.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210621T195245.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210221T194955.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210521T193719.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201221T192045.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210316T195315.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210618T193159.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210120T193637.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210711T192342.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T192709.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201218T193143.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210406T192417.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210302T192450.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210519T194550.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T193432.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210323T193103.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210419T194718.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210114T192051.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210411T193806.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201213T193151.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210203T192956.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210416T192850.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T192537.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210121T194425.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210404T192047.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210315T192509.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210706T194743.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210226T193104.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210521T193546.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T193108.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T192804.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210419T193109.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210308T194326.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210225T192523.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210510T193901.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210227T191957.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T192710.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T193235.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210720T194739.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201230T193340.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210424T192857.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210227T192612.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210731T195413.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210224T194334.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210418T193853.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210623T193946.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210613T192602.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210110T193115.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T195447.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210423T192109.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210430T192241.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210224T193240.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201227T195140.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210404T193448.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210221T193559.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210609T193043.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T193015.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210310T194908.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210110T191847.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210413T192635.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210413T192501.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T195358.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T191856.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210206T192753.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210707T193402.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201225T194843.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210113T192615.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210717T194825.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210208T193340.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210505T194714.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210112T193946.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210411T194708.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210621T192750.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T195445.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210611T194431.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210107T193357.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T192324.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210527T194209.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210327T192820.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210401T194620.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210117T193627.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210122T192343.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201217T192350.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210320T192655.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210320T194402.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210305T192552.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210312T194949.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T194112.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210403T193754.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210228T193744.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210626T194945.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210618T192720.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210801T195033.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210426T195424.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210329T192406.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210801T194419.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210526T194608.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210608T194332.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210518T192614.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210418T192316.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210606T194901.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210609T194005.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210220T192231.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210418T192623.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210529T195201.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210603T192919.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210508T194030.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210416T194558.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201227T192630.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210209T194258.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210114T192227.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210203T194050.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210627T193946.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210710T195423.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210319T195338.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210411T194402.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210305T194301.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210503T193803.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210324T194536.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210504T194107.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210321T194848.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210311T194518.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T195311.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210605T193312.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210710T194328.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210422T192604.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210106T192459.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210107T193224.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210627T194120.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210101T194859.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210424T195037.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210529T193323.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210428T193545.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210510T195301.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210312T192642.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210516T193653.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201213T192406.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210313T192720.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210222T193210.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210307T191843.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210304T195329.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T194328.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201216T193206.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210227T192746.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210701T192248.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210704T194810.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210117T194239.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210428T192012.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210603T193533.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210626T192929.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210109T193246.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210620T195254.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210610T194443.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210527T194823.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210403T193448.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210505T194235.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T194506.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210513T192646.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201218T192356.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210214T194252.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210224T193720.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210729T195350.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210514T192334.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210111T192235.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210216T195129.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210721T193635.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210411T194841.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210113T194610.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T194639.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201214T195300.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210313T191933.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210112T192720.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210610T194136.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210601T194752.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210608T192318.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210226T192930.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210429T194119.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210501T193923.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210502T194928.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210218T191908.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210107T193051.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210131T192000.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210805T193103.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210516T191946.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210329T193324.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210612T192620.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210117T193800.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210610T195056.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210330T194306.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210307T194752.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201216T194301.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210423T194258.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210207T193023.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210106T193417.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210317T193741.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210511T194810.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210601T194004.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210417T194314.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201225T192832.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210424T193030.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210222T193037.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210225T194600.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210527T192809.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210401T193544.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T192629.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210102T194709.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201229T192251.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210117T193014.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210503T192843.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210531T192808.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210305T192245.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210617T192611.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210324T193137.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210528T193603.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210423T193645.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210122T193436.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210312T192335.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210514T193120.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210327T194705.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210320T192829.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210624T192952.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210514T195309.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210211T192813.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T192631.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210203T193129.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210206T194628.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210602T192653.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210313T192546.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210627T194906.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210115T192553.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T194753.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210607T191931.fits',
# ...
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210612T193847.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210529T193015.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210122T193917.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210101T194559.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210802T192452.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210507T192810.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210710T192313.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210329T195334.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210210T195328.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210513T194832.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210204T194336.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210302T194837.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210113T194437.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210106T192632.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210212T194735.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210324T195148.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210806T194250.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210405T195430.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210106T195055.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210206T192006.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210611T193027.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210518T192308.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210225T192043.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210526T194434.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210530T192843.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210218T192349.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210407T193246.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210319T192505.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201216T193954.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210605T193751.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T194109.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210429T195331.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T194419.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210428T193719.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210806T195020.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210115T193032.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210627T193025.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210426T192957.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210225T192349.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210105T192933.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210719T193731.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210601T192736.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210102T193241.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210216T194822.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210625T192614.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210625T193709.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201229T193957.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201228T195340.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201222T195043.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210304T194715.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210112T194601.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210315T192816.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210525T193111.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210628T192049.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210330T194745.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210521T195426.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210116T193750.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210211T192200.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210606T192234.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210411T193021.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T192434.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210205T193300.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210531T194957.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210320T194229.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210322T194313.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210627T194253.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201229T192424.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T192906.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210510T192021.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210307T192017.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210625T192747.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210806T195154.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210130T192718.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210221T192331.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210307T193551.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210807T192144.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210303T195036.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210617T194144.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210510T195128.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210213T193257.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210105T192013.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210106T193724.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210203T192341.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210129T192825.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210517T194951.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210712T192204.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201217T192656.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210613T194617.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210131T194909.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210130T194252.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210316T194353.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210317T194048.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210416T194425.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210510T194954.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210629T194432.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210428T192319.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210504T193012.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210708T194604.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210731T192138.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210602T193921.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201219T192237.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210219T192009.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210202T195412.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201216T193512.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210601T194311.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210728T193853.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T193324.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210418T194931.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210731T193056.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201230T192247.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210609T193350.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210228T194839.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210328T194241.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210402T195336.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210402T194548.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210123T193901.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210101T191934.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210403T192836.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210524T195248.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210503T195208.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210701T194743.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210402T194242.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210625T194324.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210117T194713.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T192437.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210507T195325.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201230T192113.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210418T192931.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210220T193325.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210308T194151.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210223T191926.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210302T195010.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210404T192700.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210214T192107.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210805T192623.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210310T192723.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201219T194113.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210515T191904.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210529T194243.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20201226T192754.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210205T192340.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210413T191849.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210515T194704.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210429T193505.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210610T193044.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210416T194251.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210429T195024.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210110T194820.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210628T194238.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210603T195106.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210421T193551.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210719T194346.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210708T194910.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210227T192919.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210705T195225.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210315T194703.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210216T193113.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210303T193019.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210517T192457.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210612T195250.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210529T193629.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210215T193940.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210414T194122.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210404T195204.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210226T195314.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210404T195031.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210615T192705.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210523T195127.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210307T193110.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210209T192246.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210212T195348.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210515T195011.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210508T193243.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210425T192403.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210609T191948.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210507T194036.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210526T192901.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210426T192824.fits',
#  '/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210523T193555.fits',
#  ...]

# %%
# Open FITS File
hdul = fits.open('/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T195226.fits')
hdul.info()
# Out:
# Filename: /xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/neidL2_20210509T195226.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     746   ()
#   1  SCIFLUX       1 ImageHDU        12   (9216, 122)   float32
#   2  SKYFLUX       1 ImageHDU        12   (9216, 122)   float32
#   3  CALFLUX       1 ImageHDU        12   (9216, 122)   float32
#   4  SCIVAR        1 ImageHDU        12   (9216, 122)   float32
#   5  SKYVAR        1 ImageHDU        12   (9216, 122)   float32
#   6  CALVAR        1 ImageHDU        12   (9216, 122)   float32
#   7  SCIWAVE       1 ImageHDU      2085   (9216, 122)   float64
#   8  SKYWAVE       1 ImageHDU      2085   (9216, 122)   float64
#   9  CALWAVE       1 ImageHDU      2085   (9216, 122)   float64
#  10  TELLURIC      1 ImageHDU        12   (9216, 122)   float64
#  11  SKY           1 ImageHDU         8   ()
#  12  CCFS          1 ImageHDU       515   (804, 122)   float64
#  13  ACTIVITY      1 BinTableHDU     41   15R x 12C   [10A, D, D, 20A, D, D, D, D, D, 13A, 13A, 20A]
#  14  EXPMETER      1 ImageHDU        25   (58, 122, 7)   float64

# %%
# Get Flux and Wave Data
wave = hdul['SCIWAVE'].data
flux = hdul['SCIFLUX'].data

# Print Flux and Wave Data Shape 
print('Flux Data Shape:', flux.shape)
print('Wave Data Shape:', wave.shape) # both have 122 spectral orders!
# Out:
# Flux Data Shape: (122, 9216)
# Wave Data Shape: (122, 9216)

# %%
# Universal Graph Styling
COLOR = 'k'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
plt.rcParams["font.family"] = "Helvetica"
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
def chunked_continuum_fit(x, y, percentile_cut=95.0, nchunks=15, deg=5):
    chunks_x = np.zeros(nchunks) #Chunk up spectrum and store mini-spectrum chunks in lists
    chunks_y = np.zeros(nchunks)
    npixels = len(x)
    pixels_per_chunk = npixels / nchunks
    for i in range(nchunks): #Loop through each chunk
        chunk_i1 = np.int(i*pixels_per_chunk)
        chunk_i2 = np.int((i+1)*pixels_per_chunk)
        if chunk_i2 > npixels: #Chop end of last chunk
            chunk_i2 = npixels
        chunks_y[i] = np.nanpercentile(y[chunk_i1:chunk_i2], percentile_cut) #Chunk y is xxth percentile of chunk
        chunks_x[i] = 0.5*(x[chunk_i1:chunk_i2][0]+x[chunk_i1:chunk_i2][-1]) #Chunk x is just center of chunk
    smooth_y = savgol_filter(chunks_y, 11, 1) # add some smoothin to avoid "falling" into lines
    pfit = np.polyfit(chunks_x, smooth_y, deg=deg) #fit polynomial to chunks
    cs = CubicSpline(chunks_x, chunks_y)
    return np.polyval(pfit, x), cs, chunks_x, chunks_y #Return continuum array generated from polynomial fit

# %%
# DATA CUBE FORMAT
# For each order (range 40 thru 110): Find all good lines and add to data cube
# 
# Reference File Name
#    Order 40
#       Line 2 
#          Centroid 4567.35
#          Centroid Pix Val 1245
#          Other Properties 
# File @ Time 
#    Order 
#       Corresponding Line (2)
#          Centroid 
#          Centroid Pix Val 
#          Property 
# etc...
#
#
#
#

# %%
# Create Nested Dictionary of Values (The Initial-Reference Datetime Only)
start_time = time.time()
nested_dict = {}
for order_value in range(40, 111):
    # Get the Order (40-110)
    order = order_value
        
    # Replace NaN Values with Zero of Numpy Array for Wave and Flux
    x = np.nan_to_num(np.array(wave[order,:]))
    y = np.nan_to_num(np.array(flux[order,:]))
    pix_array = np.arange(flux.shape[1])

    # Set NaNs to zero
    flux[np.isnan(flux)] = 0
    wave[np.isnan(wave)] = 0

    # Combine 'x' and 'y' into Single Array
    order_data = np.stack((x, y), axis=1)

    # Blaze Correction
    unkfit, cs,chunks_x, chunks_y = chunked_continuum_fit(pix_array,flux[order,:],percentile_cut=90.0, nchunks=100, deg=7)
    model = SkewedGaussianModel()
    params = model.make_params(amplitude=2e5, center=4500, sigma=1000, gamma=1)
    result = model.fit(chunks_y, params, x=chunks_x)
    skew_blaze = np.interp(pix_array, chunks_x, result.best_fit)
    correction = flux[order,:]/skew_blaze
    
    # First Derivative of Blaze-Removed Spectrum (To Find Zero-Crossings)
    derivative = np.gradient(correction) 

    # Second Derivative of Blaze-Removed Spectrum (To Remove Most Noise)
    derivative2 = np.gradient(derivative) 

    # Smoothed First & Second Derivatives
    smooth_derivative = savgol_filter(derivative, 11, 5)
    smooth_derivative2 = savgol_filter(derivative2, 11, 5)

    # Third Derivative of Blaze-Removed Spectrum (To Remove Duplicate Points)
    derivative3 = np.gradient(smooth_derivative2) 

    # Sort List to Split into 3 Parts and Find Avg Value of Upper Part to determine 2nd Der 'Bump' Thresholds
    sortedlist_for2 = np.sort(smooth_derivative2)
    splitlist = np.array_split(sortedlist_for2, 3)

    # Find Zero Crossings
    zero_crossing1 = np.where((smooth_derivative2 > np.mean(splitlist[2])))[0] 
    zero_crossing2 = np.where(np.diff(np.signbit(derivative3)))
    zerolist1 = zero_crossing1.tolist()
    zerolist2 = np.array(zero_crossing2).tolist()
    zero_crossings = np.array(list(set(zerolist1).intersection(zerolist2[0]))) # final list of points!
    
    # Create List of Peak Findings and Sort List
    good_lines = []
    for zero_crossing in zero_crossings:
        # (Arpita) cut off pixels at very edge of detector
        if 20 < zero_crossing < 9000: 

            # (Arpita) Make sure first derivate is going from negative to positive
            slope = smooth_derivative[zero_crossing-1] - smooth_derivative[zero_crossing+1]

            # (Arpita) Im setting these numbers after experimenting with different slope cuts
            if -0.38 < slope < -0.01:
                good_lines.append(zero_crossing)
    good_lines.sort()

    # Delete Really Close-to-Each-Other Values
    for index, i in enumerate(good_lines):
        if good_lines[-1] == i:
            break

        i_up = good_lines[index+1]
        if ((i_up-i) < 18):
            good_lines.remove(i)
            good_lines.remove(i_up)
            
    # Loop through all Lines
    pixrange, total_count = 15, 0
    centroid_list = []   
    nested_dict['Order '+str(order)] = {}
    for linenum, val in enumerate(good_lines):
        
        # (Arpita) Chunk/Shunk Work
        schunk = correction[(good_lines[linenum]-pixrange):(good_lines[linenum]+pixrange)]
        upside = -schunk + 1
        xchunk = np.arange(len(schunk))

        # Skewed Gaussian Model 'x' and 'y' Variables to Use
        skgauss_x = good_lines[linenum]+xchunk
        skgauss_y = upside

        # Convert to Wavelength Values
        wchunk = wave[order,(good_lines[linenum]-pixrange):(good_lines[linenum]+pixrange)]

        # Create Skewed Gaussian Model Fit
        mod = SkewedGaussianModel()
        pars = mod.guess(upside, x=wchunk)
        out = mod.fit(upside, pars, x=wchunk)

        # Find the Centroid
        height_xval = np.amax(out.best_fit, axis=0) # = amplitude
        lines_data = np.stack((skgauss_x, out.best_fit), axis=1)
        height_result = np.where(lines_data == height_xval) 
        index = height_result[0]
        centroid = pars['center'].value
        centroid_pixval = np.interp(centroid, wchunk, skgauss_x) # = (lines_data[index][0])[0] = height_yval

        # Find the Normalized Amplitude
        amplitude = height_xval
        
        # Find Sigma (Pixels)
        mod2 = SkewedGaussianModel()
        pars2 = mod2.guess(skgauss_y, x=skgauss_x)
        out2 = mod2.fit(skgauss_y, pars2, x=skgauss_x)
        sigma = pars2['sigma'].value

        # Find the Skewness
        get_skew = pd.DataFrame(out.best_fit).skew()
        skew = get_skew[0]
        
        # Bound for integration
        dats = np.stack((wchunk, upside), axis=1)

        FWHM = sigma * 2.3548
        min_window = centroid - (FWHM/2)
        max_window = centroid + (FWHM/2)

        # Find the Integrated Flux
        y_values = out.best_fit
        merged_list = [(wchunk[i], y_values[i]) for i in range(0, len(wchunk))]
        result1 = [i for i in merged_list if i[0] < max_window]
        result2 = [i for i in result1 if i[0] > min_window]
        list1, list2 = zip(*result2)
        int_flux = trapz(list2, dx=5)

        # Bounds Used to make sure Centroid within Range
        xmin_bound = np.amin(skgauss_x) + 10
        xmax_bound = np.amax(skgauss_x) - 10

        # Filter Quality Checks
        filter_count = 0
        if (sigma >= 8) or (amplitude <= 0.1) or (amplitude >= 1) or (skew >= 1) or (skew <= -0.4) or (int_flux < 0.1): 
            filter_count += 1
            continue 

        # Filter where Centroids not in Range of Graph
        if (round(centroid_pixval) not in range(xmin_bound, xmax_bound)):
            filter_count += 1
            continue

        # Filter Any Duplicate Lines
        centroid_list.append(centroid)
        for index, centroid in enumerate(centroid_list):
            if index == 0:
                continue  
            centroid_down = centroid_list[index-1]
            if (abs(centroid - centroid_down)) <= 0.05:
                centroid_list.remove(centroid)
                break 
        if centroid not in centroid_list:
            filter_count += 1
            continue

        
        # Append Nested Dictionary Values
        nested_dict['Order '+str(order)]['Line '+str(total_count)] = {}
        nested_dict['Order '+str(order)]['Line '+str(total_count)]['centroid'] = centroid
        nested_dict['Order '+str(order)]['Line '+str(total_count)]['centroid_pixval'] = centroid_pixval
        nested_dict['Order '+str(order)]['Line '+str(total_count)]['amplitude'] = amplitude
        nested_dict['Order '+str(order)]['Line '+str(total_count)]['sigma'] = sigma
        nested_dict['Order '+str(order)]['Line '+str(total_count)]['skew'] = skew
        nested_dict['Order '+str(order)]['Line '+str(total_count)]['int_flux'] = int_flux
        
        # Add to Total Count of Lines
        total_count += 1

print('Completed in ',(time.time() - start_time),' seconds')

# %%
# Save the Nested Dictionary
np.save('noon_t0.npy', nested_dict) 

# Read and Print the Nested Dictionary from Saved File
noon_t0_datalist = np.load('noon_t0.npy',allow_pickle='TRUE').item()

# Fin!
print(noon_t0_datalist)

# %%
 # Create Time Axis
ref_file_time = '20210509T195226' 
time_folder = {}
noon_t0_datalist = np.load('noon_t0.npy',allow_pickle='TRUE').item()
time_folder['Time '+str(ref_file_time)] = noon_t0_datalist

noon_t0_datalist = np.load('noon_t0.npy',allow_pickle='TRUE').item()
ref_file_time = '20210509T195226' 

# Save Final Dictionary @ Checkpoint
np.save('data_cube_v2.0.0.npy', time_folder)

# %%
# Make the Entire Noon Data-Cube
start_time = time.time()

# Prepare Directory
file_dir = os.listdir('/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/')
NEID_Sun = [s for s in file_dir if 'neid' in s]
NEID_Sun.sort()

# Load Current Cube
time_folder = np.load('data_cube_v2.0.0.npy',allow_pickle='TRUE').item()
ref_file_time = '20210509T195226' 

# Loop through all Files
for file in NEID_Sun:
    
    # Get the Date-Time for File
    file.replace('.fits', '')
    file_time = (file.split('_',1)[1]).partition('.')[0]
    
    # Check if already Looped 
    completed_times = []
    for timeval in time_folder:
        timeval = timeval.replace('Time ', '')
        completed_times.append(timeval)
    
    if file_time in completed_times:
        continue
        
    # Open the FITS File
    hdul = fits.open('/xdisk/cbender/cbender/sandbox/solar_data_noon_half_hour/'+str(file))
        
    # Get Flux and Wave Data
    flux = hdul['SCIFLUX'].data
    wave = hdul['SCIWAVE'].data

    # Loop through Orders 40-110
    time_folder['Time '+str(file_time)] = {}
    for order in range(40,111):
        # Replace NaN Values with Zero of Numpy Array for Wave and Flux
        x = np.nan_to_num(np.array(wave[order,:]))
        y = np.nan_to_num(np.array(flux[order,:]))
        pix_array = np.arange(flux.shape[1])

        # Set NaNs to zero
        flux[np.isnan(flux)] = 0
        wave[np.isnan(wave)] = 0

        # Combine 'x' and 'y' into Single Array
        order_data = np.stack((x, y), axis=1)

        # Blaze Correction
        unkfit, cs,chunks_x, chunks_y = chunked_continuum_fit(pix_array,flux[order,:],percentile_cut=90.0, nchunks=100, deg=7)
        model = SkewedGaussianModel()
        params = model.make_params(amplitude=2e5, center=4500, sigma=1000, gamma=1)
        result = model.fit(chunks_y, params, x=chunks_x)
        skew_blaze = np.interp(pix_array, chunks_x, result.best_fit)
        correction = flux[order,:]/skew_blaze
        
        # Get Reference File Lines for Order
        ref_lines = time_folder['Time '+str(ref_file_time)]['Order '+str(order)]
        
        # Loop through each Reference Line and find Matching Fit
        time_folder['Time '+str(file_time)]['Order '+str(order)] = {}
        for index, ref_line in enumerate(ref_lines): 
            # Reference Centroid (in Pixels)
            ref_centroid_pixval = ref_lines['Line '+str(index)]['centroid_pixval'] - 15
            rounded_ref_centroid_pixval = int(round(ref_centroid_pixval))
            
            # (Arpita) Chunk/Shunk Work
            schunk = correction[(rounded_ref_centroid_pixval-pixrange):(rounded_ref_centroid_pixval+pixrange)]
            upside = np.nan_to_num(-schunk + 1)
            xchunk = np.arange(len(schunk))

            # Skewed Gaussian Model 'x' and 'y' Variables to Use
            skgauss_x = rounded_ref_centroid_pixval+xchunk
            skgauss_y = upside

            # Convert to Wavelength Values
            wchunk = wave[order,(rounded_ref_centroid_pixval-pixrange):(rounded_ref_centroid_pixval+pixrange)]

            # Create Skewed Gaussian Model Fit
            mod = SkewedGaussianModel()
            pars = mod.guess(upside, x=wchunk)
                
            try:
                out = mod.fit(upside, pars, x=wchunk)
            except ValueError:
                continue
                
            
            # Find the Centroid
            height_xval = np.amax(out.best_fit, axis=0) # = amplitude
            lines_data = np.stack((skgauss_x, out.best_fit), axis=1)
            height_result = np.where(lines_data == height_xval) 
            centroid = pars['center'].value
            centroid_pixval = np.interp(centroid, wchunk, skgauss_x) # = (lines_data[index][0])[0] = height_yval

            # Find the Normalized Amplitude
            amplitude = height_xval

            # Find Sigma (Pixels)
            mod2 = SkewedGaussianModel()
            pars2 = mod2.guess(skgauss_y, x=skgauss_x)
            out2 = mod2.fit(skgauss_y, pars2, x=skgauss_x)
            sigma = pars2['sigma'].value

            # Find the Skewness
            get_skew = pd.DataFrame(out.best_fit).skew()
            skew = get_skew[0]
        
            # Bound for integration
            dats = np.stack((wchunk, upside), axis=1)
            FWHM = sigma * 2.3548
            min_window = centroid - (FWHM/2)
            max_window = centroid + (FWHM/2)

            # Find the Integrated Flux
            y_values = out.best_fit
            merged_list = [(wchunk[i], y_values[i]) for i in range(0, len(wchunk))]
            result1 = [i for i in merged_list if i[0] < max_window]
            result2 = [i for i in result1 if i[0] > min_window]
            list1, list2 = zip(*result2)
            int_flux = trapz(list2, dx=5)
            
            # Append Nested Dictionary Values 
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)] = {}
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)]['centroid'] = centroid
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)]['centroid_pixval'] = centroid_pixval
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)]['amplitude'] = amplitude
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)]['sigma'] = sigma
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)]['skew'] = skew 
            time_folder['Time '+str(file_time)]['Order '+str(order)]['Line '+str(index)]['int_flux'] = int_flux 
            
        # Save File Data to Dictionary Checkpoint
        if order == 110:
            np.save('data_cube_v2.0.0.npy', time_folder) 
                                               
print('Completed in ',(time.time() - start_time),' seconds')
